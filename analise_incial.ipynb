# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
agenda = pd.read_csv('agendamento_mensal.csv')
df = pd.DataFrame(agenda)

# %%
display(df.describe())
# Out:
#        agendamento  atendidos  cancelados
# count    22.000000  22.000000   22.000000
# mean      6.000000   4.954545    1.045455
# std       1.718249   2.034869    1.045502
# min       1.000000   0.000000    0.000000
# 25%       6.000000   4.000000    0.000000
# 50%       6.500000   6.000000    1.000000
# 75%       7.000000   6.000000    1.750000
# max       8.000000   7.000000    3.000000

# %%
#somando o agendamento, o atendimento e o cancelamento com a função sum() do Numpy
soma_agendamento = np.sum(df['agendamento'])
print(f'O Total de Agendamento foi {soma_agendamento}.')

soma_atendidos = np.sum(df['atendidos'])
print(f'Total de Atendimento foi {soma_atendidos}.')

soma_cancelados = np.sum(df['cancelados'])
print(f'O Total de cancelamento foi {soma_cancelados}.')
# Out:
# O Total de Agendamento foi 132.
# Total de Atendimento foi 109.
# O Total de cancelamento foi 23.

# %%
#Gerando um gráfico de Pizza para atendimento e cancelamento
rotulos = ['Atendidos','Cancelados']
valores = [soma_atendidos,soma_cancelados]
plt.pie(valores, labels=rotulos, autopct='%1.1f%%')
plt.title('Proporção de Atendimento e Cancelamento')
plt.show()

# %%
sns.pairplot(df)
# Out:
# c:\Users\User\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dados = { 'semana':['primeira','segunda','terceira','quarta','quinta',]
         ,'agendados':[29,25,30,30,19]
         ,'atendidos':[26,19,23,28,18]
         ,'cancelados':[3,6,7,2,1]}

# %%
novo_df = pd.DataFrame(dados)

# %%
plt.bar(novo_df['semana'], novo_df['agendados'])
plt.bar(novo_df['semana'], novo_df['atendidos'],color = 'orange')
plt.bar(novo_df['semana'], novo_df['cancelados'],color = 'red')
plt.title('Proporção de Agendamentos,Atendimentos e cancelamentos Semanais')
plt.xlabel('Agendamento em Azul,Atendimanto em Laranja \n e Canecamento em Vermelho')
plt.ylabel('')
plt.show()

# %%
plt.plot(novo_df['semana'], novo_df['atendidos'])
plt.plot(novo_df['semana'], novo_df['cancelados'])
plt.title('Período semanal do mês de Julho')
plt.xlabel('')
plt.ylabel('Atendidos em azul X Cancelados em Laranja')
plt.xticks()
plt.show()

# %%
display(df.describe)
# Out:
# <bound method NDFrame.describe of         semana  agendamento  atendidos  cancelados
# 0   01/07/2024            6          4           2
# 1   02/07/2024            7          5           2
# 2   03/07/2024            6          6           0
# 3   04/07/2024            7          7           0
# 4   05/07/2024            3          0           3
# 5   09/07/2024            8          7           1
# 6   10/07/2024            7          6           1
# 7   11/07/2024            7          4           3
# 8   12/07/2024            3          2           1
# 9   15/07/2024            6          4           2
# 10  16/07/2024            7          6           1
# 11  17/07/2024            7          6           1
# 12  18/07/2024            5          5           0
# 13  19/07/2024            5          2           3
# 14  22/07/2024            7          6           1
# 15  23/07/2024            7          7           0
# 16  24/07/2024            6          6           0
# ...

# %%
media_agendamento = df['agendamento'].mean()
mediana_agendamento = df['agendamento'].median()
q1_agendamento = df['agendamento'].quantile(0.25)
q3_agendamento = df['agendamento'].quantile(0.75)

# Criar um boxplot com Seaborn
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['agendamento'])

# Adicionando linhas para média, mediana, Q1 e Q3
plt.axvline(media_agendamento, color='r', linestyle='--', label='Média')
plt.axvline(mediana_agendamento, color='g', linestyle='--', label='Mediana')
plt.axvline(q1_agendamento, color='b', linestyle='--', label='Q1 (25%)')
plt.axvline(q3_agendamento, color='orange', linestyle='--', label='Q3 (75%)')

# Configurando o título e as legendas
plt.title('Agendamento Diário com Média, Mediana, Q1 e Q3')
plt.xlabel('Boxplot AGENDAMENTO')
plt.legend()
plt.show()

# %%
media_atendidos= df['atendidos'].mean()
mediana_atendidos = df['atendidos'].median()
q1_atendidos = df['atendidos'].quantile(0.25)
q3_atendidos = df['atendidos'].quantile(0.75)

# Criar um boxplot com Seaborn
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['atendidos'])

# Adicionando linhas para média, mediana, Q1 e Q3
plt.axvline(media_atendidos, color='red', linestyle='--', label='Média')
plt.axvline(mediana_atendidos, color='g', linestyle='--', label='Mediana')
plt.axvline(q1_atendidos, color='b', linestyle='--', label='Q1 (25%)')
plt.axvline(q3_atendidos, color='orange', linestyle='--', label='Q3 (75%)')

# Configurando o título e as legendas
plt.title('Atendimentos Diário com Média, Mediana, Q1 e Q3')
plt.xlabel('Boxplot ATENDIMENTO')
plt.legend()
plt.show()

# %%
media_cancelados = df['cancelados'].mean()
mediana_cancelados = df['cancelados'].median()
q1_cancelados = df['cancelados'].quantile(0.25)
q3_cancelados = df['cancelados'].quantile(0.75)

# Criar um boxplot com Seaborn
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['cancelados'])

# Adicionando linhas para média, mediana, Q1 e Q3
plt.axvline(media_cancelados, color='r', linestyle='--', label='Média')
plt.axvline(media_cancelados, color='g', linestyle='--', label='Mediana')
plt.axvline(q1_cancelados, color='b', linestyle='--', label='Q1 (25%)')
plt.axvline(q3_cancelados, color='orange', linestyle='--', label='Q3 (75%)')

# Configurando o título e as legendas
plt.title('Agendamento Diário com Média, Mediana, Q1 e Q3')
plt.xlabel('Boxplot CANCELAMENTO')
plt.legend()
plt.show()
